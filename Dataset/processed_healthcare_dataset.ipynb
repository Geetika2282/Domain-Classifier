# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/healthcare_dataset.csv')

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df = df[['Medical Condition', 'Medication']]

# %%
df.head()
# Out:
#   Medical Condition   Medication
# 0            Cancer  Paracetamol
# 1           Obesity    Ibuprofen
# 2           Obesity      Aspirin
# 3          Diabetes    Ibuprofen
# 4            Cancer   Penicillin

# %%
df['Domain'] = 'Medical'
# Out:
# <ipython-input-26-efc2b73c9a0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Domain'] = 'Medical'

# %%
df
# Out:
#       Medical Condition   Medication   Domain
# 0                Cancer  Paracetamol  Medical
# 1               Obesity    Ibuprofen  Medical
# 2               Obesity      Aspirin  Medical
# 3              Diabetes    Ibuprofen  Medical
# 4                Cancer   Penicillin  Medical
# ...                 ...          ...      ...
# 55495            Asthma   Penicillin  Medical
# 55496           Obesity      Aspirin  Medical
# 55497      Hypertension    Ibuprofen  Medical
# 55498         Arthritis    Ibuprofen  Medical
# 55499         Arthritis    Ibuprofen  Medical
#
# [55500 rows x 3 columns]

# %%
df.rename(columns={'Medical Condition':'Subdomain', 'Medication':'Description'}, inplace=True)

# %%
df.size
# Out:
# 166500

# %%
df['Subdomain'].nunique()
# Out:
# 6

# %%
df.head()
# Out:
#   Subdomain  Description   Domain
# 0    Cancer  Paracetamol  Medical
# 1   Obesity    Ibuprofen  Medical
# 2   Obesity      Aspirin  Medical
# 3  Diabetes    Ibuprofen  Medical
# 4    Cancer   Penicillin  Medical

# %%
df.to_csv('processed_healthcare_data.csv', index=False)
